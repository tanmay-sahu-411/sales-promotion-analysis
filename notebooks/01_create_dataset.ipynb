# %% [markdown]
# # Dataset Creation - Sales Promotion Analysis
#
# This notebook creates a synthetic promotion dataset using Pandas.

# %%
import pandas as pd

# %%
data = {
    "Date": [
        "2024-01-01","2024-01-01","2024-01-01","2024-01-01",
        "2024-01-02","2024-01-02","2024-01-02","2024-01-02",
        "2024-01-03","2024-01-03","2024-01-03","2024-01-03",
        "2024-01-04","2024-01-04","2024-01-04","2024-01-04",
        "2024-01-05","2024-01-05","2024-01-05","2024-01-05"
    ],
    "Product": [
        "Headphones","Laptop","Keyboard","Mouse",
        "Headphones","Laptop","Keyboard","Mouse",
        "Headphones","Laptop","Keyboard","Mouse",
        "Headphones","Laptop","Keyboard","Mouse",
        "Headphones","Laptop","Keyboard","Mouse"
    ],
    "Category": [
        "Electronics","Electronics","Accessories","Accessories"
    ] * 5,
    "City": [
        "Bangalore","Delhi","Mumbai","Bangalore",
        "Delhi","Mumbai","Bangalore","Delhi",
        "Mumbai","Bangalore","Delhi","Mumbai",
        "Bangalore","Delhi","Mumbai","Bangalore",
        "Delhi","Mumbai","Bangalore","Delhi"
    ],
    "Units_Sold": [
        120,20,80,150,
        160,22,70,130,
        210,18,95,140,
        180,25,85,160,
        200,30,90,170
    ],
    "Original_Price": [
        2000,50000,1500,800
    ] * 5,
    "Promo_Price": [
        1600,45000,1200,600,
        1500,47000,1400,650,
        1400,48000,1300,700,
        1300,46000,1200,650,
        1500,44000,1100,600
    ]
}

df = pd.DataFrame(data)

df.head()
# Out:
#          Date     Product     Category       City  Units_Sold  Original_Price  \
# 0  2024-01-01  Headphones  Electronics  Bangalore         120            2000
# 1  2024-01-01      Laptop  Electronics      Delhi          20           50000
# 2  2024-01-01    Keyboard  Accessories     Mumbai          80            1500
# 3  2024-01-01       Mouse  Accessories  Bangalore         150             800
# 4  2024-01-02  Headphones  Electronics      Delhi         160            2000
#
#    Promo_Price
# 0         1600
# 1        45000
# 2         1200
# 3          600
# 4         1500

# %%
df.to_csv("../data/promotion_data.csv", index=False)

# %%
import os

print(os.listdir("../data"))
# Out:
# ['promotion_data.csv']
